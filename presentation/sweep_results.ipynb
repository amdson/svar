# %% [markdown]
# # Sweep results
#
# Organizes a `run_head_sweep.sh` run and plots PCC curves across panels. Globs every `model.metrics.jsonl` under `RESULTS_DIR`, parses each run's knobs out of its directory name (`cache__variant_head_pool_std_ws_lr_wd_ep`), and plots the chosen metrics over epochs — one figure per metric, one **panel per `FACET_BY`** value, one line per run (colored by `SERIES_BY`).
#
# Set `RESULTS_DIR`, `METRICS`, `FACET_BY`, and `SERIES_BY` in the config cell. Defaults: mean PCC + panicle-number PCC, faceted by variant, one line per cache x head x standardizer.

# %%
import json
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Root the sweep wrote heads under (relative to this notebook in train_pipeline/).
RESULTS_DIR = Path("../trained_heads/std_checks")

# (column in the jsonl, short label) for each metric to plot — one figure each.
METRICS = [
    ("val/mean_pcc",                    "mean PCC"),
    ("val/pcc/Panicle number per plant", "Panicle number PCC"),
]

# One panel per distinct value of this knob; one line per distinct combo of these.
FACET_BY   = "variant"
SERIES_BY  = ["cache", "head", "standardizer"]

# %% [markdown]
# ## Discover + parse runs
#
# Each run dir is `cache__variant_head_pool_std_ws_lr_wd_ep`. The cache tag itself contains underscores, so split on the `__` first, then positionally on the suffix. The cache column is shortened to whatever distinguishes the runs (the shared prefix is dropped, the base cache becomes `base`) for readable labels.

# %%
def load_metrics(path):
    """Read a JSONL sidecar into a DataFrame, tolerating a half-written last line."""
    rows = []
    with open(path) as f:
        for line in f:
            line = line.strip()
            if not line:
                continue
            try:
                rows.append(json.loads(line))
            except json.JSONDecodeError:
                continue
    return pd.DataFrame(rows)

def parse_run(run_name):
    """cache__variant_head_pool_std_ws_lr_wd_ep -> dict of knobs."""
    cache, rest = run_name.split("__", 1)
    parts = rest.split("_")
    variant, head, pool, standardizer, ws = parts[:5]
    kv = {p[:2]: p[2:] for p in parts[5:]}   # lr1e-3 -> {'lr': '1e-3'}, etc.
    return {"cache": cache, "variant": variant, "head": head, "pool": pool,
            "standardizer": standardizer, "ws": ws,
            "lr": kv.get("lr"), "wd": kv.get("wd"), "ep": kv.get("ep")}

metrics_files = sorted(RESULTS_DIR.rglob("model.metrics.jsonl"))
runs = {}      # run_name -> {**knobs, 'df': DataFrame}
for p in metrics_files:
    run_name = p.parent.name
    runs[run_name] = {**parse_run(run_name), "df": load_metrics(p)}

info = pd.DataFrame({k: {c: v[c] for c in
                         ("cache", "variant", "head", "pool", "standardizer", "ws", "lr", "wd", "ep")}
                     for k, v in runs.items()}).T

# Shorten the cache tag by dropping the prefix common to every run (keeps labels short);
# the cache that IS that prefix becomes 'base'.
caches = info["cache"].unique().tolist()
if len(caches) > 1:
    common = caches[0]
    for c in caches[1:]:
        while not c.startswith(common):
            common = common[:-1]
    shorten = lambda c: c[len(common):].lstrip("_") or "base"
    info["cache"] = info["cache"].map(shorten)
    for name in runs:
        runs[name]["cache"] = shorten(runs[name]["cache"])

print(f"{len(runs)} runs under {RESULTS_DIR}")
for col in ("cache", "variant", "head", "standardizer", "ws", "lr", "wd", "ep"):
    print(f"  {col:13s}: {sorted(info[col].unique())}")
# Out:
# 24 runs under ../trained_heads/std_checks
#   cache        : ['base', 'snponly']
#   variant      : ['absolute', 'centered', 'refdelta']
#   head         : ['linear', 'mlp']
#   standardizer : ['perdim', 'rms']
#   ws           : ['ws1']
#   lr           : ['1e-3']
#   wd           : ['1e-4']
#   ep           : ['15']

# %% [markdown]
# ## Final-epoch leaderboard
#
# Best (max over epochs) validation PCC per run for each plotted metric, sorted by mean PCC. A quick way to see which configs won before reading the curves.

# %%
def best_val(df, col):
    if col not in df.columns:
        return np.nan
    s = df[col].dropna()
    return s.max() if len(s) else np.nan

board = info.copy()
for col, label in METRICS:
    board[f"best {label}"] = [best_val(runs[name]["df"], col) for name in board.index]
sort_col = f"best {METRICS[0][1]}"
board = board.sort_values(sort_col, ascending=False)
cols = ["cache", "variant", "head", "standardizer"] + [f"best {l}" for _, l in METRICS]
board[cols].round(3)
# Out:
#                                                       cache   variant    head  \
# sativas413_carbon500m_hw500__absolute_mlp_sum_p...     base  absolute     mlp
# sativas413_carbon500m_hw500__refdelta_mlp_sum_p...     base  refdelta     mlp
# sativas413_carbon500m_hw500__centered_mlp_sum_p...     base  centered     mlp
# sativas413_carbon500m_hw500_snponly__refdelta_m...  snponly  refdelta     mlp
# sativas413_carbon500m_hw500_snponly__centered_m...  snponly  centered     mlp
# sativas413_carbon500m_hw500_snponly__absolute_m...  snponly  absolute     mlp
# sativas413_carbon500m_hw500__absolute_mlp_sum_r...     base  absolute     mlp
# sativas413_carbon500m_hw500__centered_mlp_sum_r...     base  centered     mlp
# sativas413_carbon500m_hw500__refdelta_mlp_sum_r...     base  refdelta     mlp
# sativas413_carbon500m_hw500__absolute_linear_su...     base  absolute  linear
# sativas413_carbon500m_hw500__refdelta_linear_su...     base  refdelta  linear
# sativas413_carbon500m_hw500__centered_linear_su...     base  centered  linear
# sativas413_carbon500m_hw500__absolute_linear_su...     base  absolute  linear
# sativas413_carbon500m_hw500__refdelta_linear_su...     base  refdelta  linear
# sativas413_carbon500m_hw500__centered_linear_su...     base  centered  linear
# sativas413_carbon500m_hw500_snponly__centered_l...  snponly  centered  linear
# sativas413_carbon500m_hw500_snponly__refdelta_l...  snponly  refdelta  linear
# sativas413_carbon500m_hw500_snponly__absolute_l...  snponly  absolute  linear
# sativas413_carbon500m_hw500_snponly__absolute_m...  snponly  absolute     mlp
# sativas413_carbon500m_hw500_snponly__centered_m...  snponly  centered     mlp
# sativas413_carbon500m_hw500_snponly__refdelta_m...  snponly  refdelta     mlp
# sativas413_carbon500m_hw500_snponly__centered_l...  snponly  centered  linear
# sativas413_carbon500m_hw500_snponly__refdelta_l...  snponly  refdelta  linear
# sativas413_carbon500m_hw500_snponly__absolute_l...  snponly  absolute  linear
#
#                                                    standardizer  \
# sativas413_carbon500m_hw500__absolute_mlp_sum_p...       perdim
# sativas413_carbon500m_hw500__refdelta_mlp_sum_p...       perdim
# sativas413_carbon500m_hw500__centered_mlp_sum_p...       perdim
# sativas413_carbon500m_hw500_snponly__refdelta_m...       perdim
# sativas413_carbon500m_hw500_snponly__centered_m...       perdim
# sativas413_carbon500m_hw500_snponly__absolute_m...       perdim
# sativas413_carbon500m_hw500__absolute_mlp_sum_r...          rms
# sativas413_carbon500m_hw500__centered_mlp_sum_r...          rms
# sativas413_carbon500m_hw500__refdelta_mlp_sum_r...          rms
# sativas413_carbon500m_hw500__absolute_linear_su...          rms
# sativas413_carbon500m_hw500__refdelta_linear_su...          rms
# sativas413_carbon500m_hw500__centered_linear_su...          rms
# sativas413_carbon500m_hw500__absolute_linear_su...       perdim
# sativas413_carbon500m_hw500__refdelta_linear_su...       perdim
# sativas413_carbon500m_hw500__centered_linear_su...       perdim
# sativas413_carbon500m_hw500_snponly__centered_l...       perdim
# sativas413_carbon500m_hw500_snponly__refdelta_l...       perdim
# sativas413_carbon500m_hw500_snponly__absolute_l...       perdim
# sativas413_carbon500m_hw500_snponly__absolute_m...          rms
# sativas413_carbon500m_hw500_snponly__centered_m...          rms
# sativas413_carbon500m_hw500_snponly__refdelta_m...          rms
# sativas413_carbon500m_hw500_snponly__centered_l...          rms
# sativas413_carbon500m_hw500_snponly__refdelta_l...          rms
# sativas413_carbon500m_hw500_snponly__absolute_l...          rms
#
#                                                     best mean PCC  \
# sativas413_carbon500m_hw500__absolute_mlp_sum_p...          0.588
# sativas413_carbon500m_hw500__refdelta_mlp_sum_p...          0.587
# sativas413_carbon500m_hw500__centered_mlp_sum_p...          0.587
# sativas413_carbon500m_hw500_snponly__refdelta_m...          0.581
# sativas413_carbon500m_hw500_snponly__centered_m...          0.581
# sativas413_carbon500m_hw500_snponly__absolute_m...          0.581
# sativas413_carbon500m_hw500__absolute_mlp_sum_r...          0.578
# sativas413_carbon500m_hw500__centered_mlp_sum_r...          0.574
# sativas413_carbon500m_hw500__refdelta_mlp_sum_r...          0.574
# sativas413_carbon500m_hw500__absolute_linear_su...          0.550
# sativas413_carbon500m_hw500__refdelta_linear_su...          0.549
# sativas413_carbon500m_hw500__centered_linear_su...          0.549
# sativas413_carbon500m_hw500__absolute_linear_su...          0.537
# sativas413_carbon500m_hw500__refdelta_linear_su...          0.536
# sativas413_carbon500m_hw500__centered_linear_su...          0.536
# sativas413_carbon500m_hw500_snponly__centered_l...          0.517
# sativas413_carbon500m_hw500_snponly__refdelta_l...          0.517
# sativas413_carbon500m_hw500_snponly__absolute_l...          0.517
# sativas413_carbon500m_hw500_snponly__absolute_m...          0.472
# sativas413_carbon500m_hw500_snponly__centered_m...          0.472
# sativas413_carbon500m_hw500_snponly__refdelta_m...          0.472
# sativas413_carbon500m_hw500_snponly__centered_l...          0.453
# sativas413_carbon500m_hw500_snponly__refdelta_l...          0.453
# sativas413_carbon500m_hw500_snponly__absolute_l...          0.453
#
#                                                     best Panicle number PCC
# sativas413_carbon500m_hw500__absolute_mlp_sum_p...                    0.790
# sativas413_carbon500m_hw500__refdelta_mlp_sum_p...                    0.791
# sativas413_carbon500m_hw500__centered_mlp_sum_p...                    0.791
# sativas413_carbon500m_hw500_snponly__refdelta_m...                    0.796
# sativas413_carbon500m_hw500_snponly__centered_m...                    0.796
# sativas413_carbon500m_hw500_snponly__absolute_m...                    0.796
# sativas413_carbon500m_hw500__absolute_mlp_sum_r...                    0.805
# sativas413_carbon500m_hw500__centered_mlp_sum_r...                    0.788
# sativas413_carbon500m_hw500__refdelta_mlp_sum_r...                    0.788
# sativas413_carbon500m_hw500__absolute_linear_su...                    0.811
# sativas413_carbon500m_hw500__refdelta_linear_su...                    0.812
# sativas413_carbon500m_hw500__centered_linear_su...                    0.812
# sativas413_carbon500m_hw500__absolute_linear_su...                    0.812
# sativas413_carbon500m_hw500__refdelta_linear_su...                    0.813
# sativas413_carbon500m_hw500__centered_linear_su...                    0.813
# sativas413_carbon500m_hw500_snponly__centered_l...                    0.816
# sativas413_carbon500m_hw500_snponly__refdelta_l...                    0.816
# sativas413_carbon500m_hw500_snponly__absolute_l...                    0.816
# sativas413_carbon500m_hw500_snponly__absolute_m...                    0.772
# sativas413_carbon500m_hw500_snponly__centered_m...                    0.772
# sativas413_carbon500m_hw500_snponly__refdelta_m...                    0.772
# sativas413_carbon500m_hw500_snponly__centered_l...                    0.730
# sativas413_carbon500m_hw500_snponly__refdelta_l...                    0.730
# sativas413_carbon500m_hw500_snponly__absolute_l...                    0.730

# %% [markdown]
# ## Curves
#
# One figure per metric, one panel per `FACET_BY` value, one line per run (val PCC over epoch). Color is consistent across all panels/figures (keyed on `SERIES_BY`) so a given config is the same color everywhere. `val/*` rows are logged once per epoch, so we drop the NaN train-only rows before plotting.

# %%
def series_label(meta):
    return " ".join(str(meta[c]) for c in SERIES_BY)

# Stable color per series label, shared across every panel and figure.
labels = sorted({series_label(m) for m in runs.values()})
cmap = plt.get_cmap("tab10" if len(labels) <= 10 else "tab20")
colors = {lab: cmap(i % cmap.N) for i, lab in enumerate(labels)}

def plot_metric(col, label):
    facets = sorted({m[FACET_BY] for m in runs.values()})
    fig, axes = plt.subplots(1, len(facets), figsize=(6 * len(facets), 4.5),
                             squeeze=False, sharey=True)
    for ax, facet in zip(axes[0], facets):
        for name, meta in runs.items():
            if meta[FACET_BY] != facet:
                continue
            df = meta["df"]
            if col not in df.columns:
                continue
            sub = df.dropna(subset=[col, "epoch"])
            if len(sub):
                lab = series_label(meta)
                ax.plot(sub["epoch"], sub[col], marker="o", ms=3,
                        color=colors[lab], label=lab)
        ax.set(xlabel="epoch", title=f"{FACET_BY} = {facet}")
        ax.grid(alpha=0.3)
    axes[0][0].set_ylabel(label)
    # One shared legend (series are identical across panels).
    handles, lbls = axes[0][0].get_legend_handles_labels()
    fig.legend(handles, lbls, loc="center left", bbox_to_anchor=(1.0, 0.5),
               fontsize=8, title=" / ".join(SERIES_BY))
    fig.suptitle(f"val {label} over training", y=1.02)
    fig.tight_layout()
    plt.show()

for col, label in METRICS:
    plot_metric(col, label)
