# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
import umap

from crop_embed.embedder import FixedWindowEmbedder

EMB_PATH = "/home/andrew.dickson/svar/sativas413_embeddings.ckpt.pt"

print(f"\nLoading cache from {EMB_PATH} …")
embedder = FixedWindowEmbedder.from_file(EMB_PATH)
cache           = embedder.cache.float()       # (n_fps, D)
sample_fp_index = embedder.sample_fp_index      # (n_samples, n_windows)
#TODO get fingerprint for each fp_index entry from ckpt.pt file

# %%
# Get the per-sample sum of the cache embeddings
# Get the per-window norms of the cache embeddings
# Get the intra-window variance of the cache embeddings (difference between fingerprint embeddings for fingerprints of the same window)
